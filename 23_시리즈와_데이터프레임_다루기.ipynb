# %%
import pandas as pd

# %%
df = pd.read_csv("person_info.csv", encoding='euc-kr')
df
# Out:
#     이름         출생일         사망일  나이   직업
# 0  홍길동  1920-07-25  1958-04-16  37  회사원
# 1  이순신  1876-06-13  1937-10-16  61   군인
# 2  이홍길  1820-05-12  1910-08-13  90   의사
# 3  곽재우  1867-11-07  1934-07-04  66  연구원
# 4  신나라  1907-05-27  1964-04-14  56  연구원
# 5  오기영  1813-03-15  1858-06-16  45  연구원
# 6  기충현  1912-06-23  1954-06-07  41  회사원
# 7  심기한  1777-04-30  1855-02-23  77   백수

# %%
df['이름']
# Out:
# 0    홍길동
# 1    이순신
# 2    이홍길
# 3    곽재우
# 4    신나라
# 5    오기영
# 6    기충현
# 7    심기한
# Name: 이름, dtype: object

# %%
df[['이름','나이','직업']]
# Out:
#     이름  나이   직업
# 0  홍길동  37  회사원
# 1  이순신  61   군인
# 2  이홍길  90   의사
# 3  곽재우  66  연구원
# 4  신나라  56  연구원
# 5  오기영  45  연구원
# 6  기충현  41  회사원
# 7  심기한  77   백수

# %%
#행

df.loc[0]
# Out:
# 이름            홍길동
# 출생일    1920-07-25
# 사망일    1958-04-16
# 나이             37
# 직업            회사원
# Name: 0, dtype: object

# %%
df.iloc[-1]#가장뒤에 있는 값
# Out:
# 이름            심기한
# 출생일    1777-04-30
# 사망일    1855-02-23
# 나이             77
# 직업             백수
# Name: 7, dtype: object

# %%
df.loc[[0,5],['이름','직업']]
# Out:
#     이름   직업
# 0  홍길동  회사원
# 5  오기영  연구원

# %%
df.iloc[[0,5],[0,4]]
# Out:
#     이름   직업
# 0  홍길동  회사원
# 5  오기영  연구원

# %%
df
# Out:
#     이름         출생일         사망일  나이   직업
# 0  홍길동  1920-07-25  1958-04-16  37  회사원
# 1  이순신  1876-06-13  1937-10-16  61   군인
# 2  이홍길  1820-05-12  1910-08-13  90   의사
# 3  곽재우  1867-11-07  1934-07-04  66  연구원
# 4  신나라  1907-05-27  1964-04-14  56  연구원
# 5  오기영  1813-03-15  1858-06-16  45  연구원
# 6  기충현  1912-06-23  1954-06-07  41  회사원
# 7  심기한  1777-04-30  1855-02-23  77   백수

# %%
df.info()#출생일, 사망일이 object type로 보고있음 다음 명령문에서 수장
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      8 non-null      object
#  1   출생일     8 non-null      object
#  2   사망일     8 non-null      object
#  3   나이      8 non-null      int64
#  4   직업      8 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 448.0+ bytes

# %%
df['출생일']=pd.to_datetime(df['출생일'])
df['사망일']=pd.to_datetime(df['사망일'])

# %%
df
# Out:
#     이름        출생일        사망일  나이   직업
# 0  홍길동 1920-07-25 1958-04-16  37  회사원
# 1  이순신 1876-06-13 1937-10-16  61   군인
# 2  이홍길 1820-05-12 1910-08-13  90   의사
# 3  곽재우 1867-11-07 1934-07-04  66  연구원
# 4  신나라 1907-05-27 1964-04-14  56  연구원
# 5  오기영 1813-03-15 1858-06-16  45  연구원
# 6  기충현 1912-06-23 1954-06-07  41  회사원
# 7  심기한 1777-04-30 1855-02-23  77   백수

# %%
df.info()#출생일, 사망일 type 날짜로 변경
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      8 non-null      object
#  1   출생일     8 non-null      datetime64[ns]
#  2   사망일     8 non-null      datetime64[ns]
#  3   나이      8 non-null      int64
#  4   직업      8 non-null      object
# dtypes: datetime64[ns](2), int64(1), object(2)
# memory usage: 448.0+ bytes

# %%
df['생존일']=df['사망일']-df['출생일']
df
# Out:
#     이름        출생일        사망일  나이   직업        생존일
# 0  홍길동 1920-07-25 1958-04-16  37  회사원 13779 days
# 1  이순신 1876-06-13 1937-10-16  61   군인 22404 days
# 2  이홍길 1820-05-12 1910-08-13  90   의사 32964 days
# 3  곽재우 1867-11-07 1934-07-04  66  연구원 24345 days
# 4  신나라 1907-05-27 1964-04-14  56  연구원 20777 days
# 5  오기영 1813-03-15 1858-06-16  45  연구원 16529 days
# 6  기충현 1912-06-23 1954-06-07  41  회사원 15324 days
# 7  심기한 1777-04-30 1855-02-23  77   백수 28422 days

# %%
df.head()
# Out:
#     이름        출생일        사망일  나이   직업        생존일
# 0  홍길동 1920-07-25 1958-04-16  37  회사원 13779 days
# 1  이순신 1876-06-13 1937-10-16  61   군인 22404 days
# 2  이홍길 1820-05-12 1910-08-13  90   의사 32964 days
# 3  곽재우 1867-11-07 1934-07-04  66  연구원 24345 days
# 4  신나라 1907-05-27 1964-04-14  56  연구원 20777 days

# %%
df.tail()
# Out:
#     이름        출생일        사망일  나이   직업        생존일
# 3  곽재우 1867-11-07 1934-07-04  66  연구원 24345 days
# 4  신나라 1907-05-27 1964-04-14  56  연구원 20777 days
# 5  오기영 1813-03-15 1858-06-16  45  연구원 16529 days
# 6  기충현 1912-06-23 1954-06-07  41  회사원 15324 days
# 7  심기한 1777-04-30 1855-02-23  77   백수 28422 days

# %%
df.columns
# Out:
# Index(['이름', '출생일', '사망일', '나이', '직업', '생존일'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
name = df['이름']
name
# Out:
# 0    홍길동
# 1    이순신
# 2    이홍길
# 3    곽재우
# 4    신나라
# 5    오기영
# 6    기충현
# 7    심기한
# Name: 이름, dtype: object

# %%
name.replace("홍길동","강동원") #기존 홍길동 값을 강동원으로 변경
# Out:
# 0    강동원
# 1    이순신
# 2    이홍길
# 3    곽재우
# 4    신나라
# 5    오기영
# 6    기충현
# 7    심기한
# Name: 이름, dtype: object

# %%
age = df['나이']
age
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: 나이, dtype: int64

# %%
age.mean()
# Out:
# 59.125

# %%
age.median()
# Out:
# 58.5

# %%
age.max()
# Out:
# 90

# %%
age.min()
# Out:
# 37

# %%
age.std()
# Out:
# 18.325918413937288

# %%
df
# Out:
#     이름        출생일        사망일  나이   직업        생존일
# 0  홍길동 1920-07-25 1958-04-16  37  회사원 13779 days
# 1  이순신 1876-06-13 1937-10-16  61   군인 22404 days
# 2  이홍길 1820-05-12 1910-08-13  90   의사 32964 days
# 3  곽재우 1867-11-07 1934-07-04  66  연구원 24345 days
# 4  신나라 1907-05-27 1964-04-14  56  연구원 20777 days
# 5  오기영 1813-03-15 1858-06-16  45  연구원 16529 days
# 6  기충현 1912-06-23 1954-06-07  41  회사원 15324 days
# 7  심기한 1777-04-30 1855-02-23  77   백수 28422 days

# %%
df[(df['직업']=='연구원')&(df['나이']>df['나이'].mean())] #직업이 연구원이고 같은 직업 중 나이가 평균값보다 많은 사람 표시
# Out:
#     이름        출생일        사망일  나이   직업        생존일
# 3  곽재우 1867-11-07 1934-07-04  66  연구원 24345 days

# %%
df[(df['직업']=='연구원')|(df['나이']>df['나이'].mean())] #직업이 연구원이거나 나이가 평균값보다 많은 사람 표시
# Out:
#     이름        출생일        사망일  나이   직업        생존일
# 1  이순신 1876-06-13 1937-10-16  61   군인 22404 days
# 2  이홍길 1820-05-12 1910-08-13  90   의사 32964 days
# 3  곽재우 1867-11-07 1934-07-04  66  연구원 24345 days
# 4  신나라 1907-05-27 1964-04-14  56  연구원 20777 days
# 5  오기영 1813-03-15 1858-06-16  45  연구원 16529 days
# 7  심기한 1777-04-30 1855-02-23  77   백수 28422 days

# %%
df['출생일'].dt.month
# Out:
# 0     7
# 1     6
# 2     5
# 3    11
# 4     5
# 5     3
# 6     6
# 7     4
# Name: 출생일, dtype: int64

# %%
df['출생일'].dt.year
# Out:
# 0    1920
# 1    1876
# 2    1820
# 3    1867
# 4    1907
# 5    1813
# 6    1912
# 7    1777
# Name: 출생일, dtype: int64

# %%
df['출생일'].dt.day
# Out:
# 0    25
# 1    13
# 2    12
# 3     7
# 4    27
# 5    15
# 6    23
# 7    30
# Name: 출생일, dtype: int64
