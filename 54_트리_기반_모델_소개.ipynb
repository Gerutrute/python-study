# %%
from sklearn.datasets import load_iris

iris = load_iris()
data, target = iris['data'], iris['target']

# %%
from sklearn.model_selection import train_test_split

train_input, test_input, train_target, test_target = train_test_split(data, target)

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

dt = DecisionTreeClassifier(max_depth=3) # max_depth : 과대적합을 막기위한 코드 // 3층에서 멈추라는 의미
dt.fit(train_input, train_target)
dt.score(test_input, test_target)
# Out:
# 0.9210526315789473

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10,10))

plot_tree(dt, feature_names=iris['feature_names'], filled=True)
# Out:
# [Text(0.375, 0.875, 'petal length (cm) <= 2.45\ngini = 0.664\nsamples = 112\nvalue = [34, 42, 36]'),
#  Text(0.25, 0.625, 'gini = 0.0\nsamples = 34\nvalue = [34, 0, 0]'),
#  Text(0.5, 0.625, 'petal length (cm) <= 4.85\ngini = 0.497\nsamples = 78\nvalue = [0, 42, 36]'),
#  Text(0.25, 0.375, 'petal width (cm) <= 1.7\ngini = 0.049\nsamples = 40\nvalue = [0, 39, 1]'),
#  Text(0.125, 0.125, 'gini = 0.0\nsamples = 38\nvalue = [0, 38, 0]'),
#  Text(0.375, 0.125, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.75, 0.375, 'petal width (cm) <= 1.75\ngini = 0.145\nsamples = 38\nvalue = [0, 3, 35]'),
#  Text(0.625, 0.125, 'gini = 0.5\nsamples = 6\nvalue = [0, 3, 3]'),
#  Text(0.875, 0.125, 'gini = 0.0\nsamples = 32\nvalue = [0, 0, 32]')]

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(train_input, train_target)
rf.score(test_input, test_target)
# Out:
# 0.9473684210526315
