# %%
import pandas as pd

perch = pd.read_csv("perch.csv")
perch
# Out:
#     length  weight
# 0      8.4     5.9
# 1     13.7    32.0
# 2     15.0    40.0
# 3     16.2    51.5
# 4     17.4    70.0
# 5     18.0   100.0
# 6     18.7    78.0
# 7     19.0    80.0
# 8     19.6    85.0
# 9     20.0    85.0
# 10    21.0   110.0
# 11    21.0   115.0
# 12    21.0   125.0
# 13    21.3   130.0
# 14    22.0   120.0
# 15    22.0   120.0
# 16    22.0   130.0
# 17    22.0   135.0
# 18    22.0   110.0
# 19    22.5   130.0
# 20    22.5   150.0
# 21    22.7   145.0
# 22    23.0   150.0
# 23    23.5   170.0
# 24    24.0   225.0
# 25    24.0   145.0
# 26    24.6   188.0
# 27    25.0   180.0
# 28    25.6   197.0
# 29    26.5   218.0
# 30    27.3   300.0
# 31    27.5   260.0
# 32    27.5   265.0
# 33    27.5   250.0
# 34    28.0   250.0
# 35    28.7   300.0
# 36    30.0   320.0
# 37    32.8   514.0
# 38    34.5   556.0
# 39    35.0   840.0
# 40    36.5   685.0
# 41    36.0   700.0
# 42    37.0   700.0
# 43    37.0   690.0
# 44    39.0   900.0
# 45    39.0   650.0
# 46    39.0   820.0
# 47    40.0   850.0
# 48    40.0   900.0
# 49    40.0  1015.0
# 50    40.0   820.0
# 51    42.0  1100.0
# 52    43.0  1000.0
# 53    43.0  1100.0
# 54    43.5  1000.0
# 55    44.0  1000.0

# %%
import matplotlib.pyplot as plt

plt.scatter(perch['length'], perch['weight'])

# %%
data = perch['length'].to_numpy()
target = perch['weight'].to_numpy()

# %%
data # 문제집 // 2차원행렬이어야 하는데 1차원 행렬
# Out:
# array([ 8.4, 13.7, 15. , 16.2, 17.4, 18. , 18.7, 19. , 19.6, 20. , 21. ,
#        21. , 21. , 21.3, 22. , 22. , 22. , 22. , 22. , 22.5, 22.5, 22.7,
#        23. , 23.5, 24. , 24. , 24.6, 25. , 25.6, 26.5, 27.3, 27.5, 27.5,
#        27.5, 28. , 28.7, 30. , 32.8, 34.5, 35. , 36.5, 36. , 37. , 37. ,
#        39. , 39. , 39. , 40. , 40. , 40. , 40. , 42. , 43. , 43. , 43.5,
#        44. ])

# %%
target
# Out:
# array([   5.9,   32. ,   40. ,   51.5,   70. ,  100. ,   78. ,   80. ,
#          85. ,   85. ,  110. ,  115. ,  125. ,  130. ,  120. ,  120. ,
#         130. ,  135. ,  110. ,  130. ,  150. ,  145. ,  150. ,  170. ,
#         225. ,  145. ,  188. ,  180. ,  197. ,  218. ,  300. ,  260. ,
#         265. ,  250. ,  250. ,  300. ,  320. ,  514. ,  556. ,  840. ,
#         685. ,  700. ,  700. ,  690. ,  900. ,  650. ,  820. ,  850. ,
#         900. , 1015. ,  820. , 1100. , 1000. , 1100. , 1000. , 1000. ])

# %%
data2 = data.reshape(-1, 1) # 자동행 1열

# %%
from sklearn.model_selection import train_test_split

train_input, test_input, train_target, test_target = train_test_split(data2, target)

# %%
from sklearn.neighbors import KNeighborsRegressor

for n in range(1,43):
    knn = KNeighborsRegressor(n_neighbors=n)
    knn.fit(train_input, train_target)
    score = knn.score(test_input, test_target)
    print("이웃수:{} / 정밀도 :{}".format(n, score))
# Out:
# 이웃수:1 / 정밀도 :0.8557911688613703
# 이웃수:2 / 정밀도 :0.9284762419697102
# 이웃수:3 / 정밀도 :0.9501103701765776
# 이웃수:4 / 정밀도 :0.9575610883404553
# 이웃수:5 / 정밀도 :0.9534711609546235
# 이웃수:6 / 정밀도 :0.9709710841739096
# 이웃수:7 / 정밀도 :0.9655481111429485
# 이웃수:8 / 정밀도 :0.9513695648382314
# 이웃수:9 / 정밀도 :0.944657329728787
# 이웃수:10 / 정밀도 :0.9276922517368681
# 이웃수:11 / 정밀도 :0.9322789772832377
# 이웃수:12 / 정밀도 :0.931114961774367
# 이웃수:13 / 정밀도 :0.9416088398421059
# 이웃수:14 / 정밀도 :0.9268573023209459
# 이웃수:15 / 정밀도 :0.9174509619552403
# 이웃수:16 / 정밀도 :0.8960039709964827
# 이웃수:17 / 정밀도 :0.8724234908677817
# 이웃수:18 / 정밀도 :0.8526965744966502
# 이웃수:19 / 정밀도 :0.8296136461278223
# 이웃수:20 / 정밀도 :0.8026093492049651
# 이웃수:21 / 정밀도 :0.7777066823915695
# 이웃수:22 / 정밀도 :0.7537200543132396
# 이웃수:23 / 정밀도 :0.7241971474759851
# 이웃수:24 / 정밀도 :0.697145414538983
# 이웃수:25 / 정밀도 :0.6702920010557833
# 이웃수:26 / 정밀도 :0.6425233080296104
# 이웃수:27 / 정밀도 :0.6137602374384672
# 이웃수:28 / 정밀도 :0.5854843260370339
# 이웃수:29 / 정밀도 :0.5570318065003848
# 이웃수:30 / 정밀도 :0.5246288256964108
# 이웃수:31 / 정밀도 :0.49304658470271123
# 이웃수:32 / 정밀도 :0.45874960370610607
# 이웃수:33 / 정밀도 :0.42303452542021225
# 이웃수:34 / 정밀도 :0.38505042161705905
# 이웃수:35 / 정밀도 :0.34631688225674506
# 이웃수:36 / 정밀도 :0.30034840489850834
# 이웃수:37 / 정밀도 :0.25443976728129936
# 이웃수:38 / 정밀도 :0.20469327415705973
# 이웃수:39 / 정밀도 :0.14518878458393814
# 이웃수:40 / 정밀도 :0.09007132444289423
# 이웃수:41 / 정밀도 :0.03191508754122452
# 이웃수:42 / 정밀도 :-0.02080788896963548

# %%
knn = KNeighborsRegressor(n_neighbors=6)
knn.fit(train_input, train_target)
# Out:
# KNeighborsRegressor(n_neighbors=6)

# %%
test_target
# Out:
# array([ 300.,  218.,  180.,  514.,  690.,  115.,  900., 1100.,   85.,
#         120.,   85.,  556.,  820.,  170.])

# %%
knn.predict(test_input)
# Out:
# array([ 274.16666667,  253.66666667,  175.        ,  582.5       ,
#         732.5       ,  121.66666667,  822.5       , 1002.5       ,
#         105.5       ,  129.16666667,  103.83333333,  677.5       ,
#         889.16666667,  157.5       ])

# %%
knn.score(test_input, test_target)
# Out:
# 0.9709710841739096

# %%
import numpy as np
np.mean(abs(test_target - knn.predict(test_input))) # 이 모델의 경우, 약 44g정도의 오차가 존재할 수 있음
# Out:
# 43.630952380952365
